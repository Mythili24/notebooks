# %%
#Importing basic libraries
import pandas as pd
from pandas import DataFrame, Series
import numpy as np

# %%
#Importing Data Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

#For reading stock data from yahoo
import yfinance as yf

#For time stamps
from datetime import datetime

# %%
# Set up End and Start times for data grab
end = datetime.now()
start = datetime(end.year-1, end.month, end.day)

# Downloading ZEE Entertainment, Canara Bank, IRCTC and Gita Renewable Energy stock data from yahoo finance
ZEEL = yf.download('ZEEL.NS', start, end, progress=False)
 
CANBK = yf.download('CANBK.NS', start, end, progress=False)

GITA = yf.download('GITARENEW.BO', start, end, progress=False)

IRCTC = yf.download('IRCTC.NS', start, end, progress=False)

#Concatenating all 4 stock data into one DataFrame
stock_df = pd.concat([ZEEL, CANBK, GITA, IRCTC])
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 992 entries, 2021-04-22 to 2022-04-20
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       992 non-null    float64
#  1   High       992 non-null    float64
#  2   Low        992 non-null    float64
#  3   Close      992 non-null    float64
#  4   Adj Close  992 non-null    float64
#  5   Volume     992 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 54.2 KB

# %%
#tickers = ['ZEEL.NS', 'IRCTC.NS', 'GITARENEW.BO', 'CANBK.NS']
ZEEL_df = yf.download(tickers = 'ZEEL.NS IRCTC.NS GITARENEW.BO CANBK.NS', interval="1mo", period='ytd', group_by='ticker', auto_adjust=True)
ZEEL_df
# Out:
# [*********************100%***********************]  4 of 4 completed
#            GITARENEW.BO                                                \
#                    Open        High         Low       Close    Volume
# Date
# 2022-02-01   157.800003  243.500000  157.800003  198.500000   60381.0
# 2022-02-17          NaN         NaN         NaN         NaN       NaN
# 2022-03-01   208.399994  229.699997  183.300003  199.449997  143987.0
# 2022-04-01   195.000000  204.000000  187.000000  189.850006   17507.0
# 2022-04-05   196.800003  196.800003  180.399994  189.000000   14318.0
#
#                ZEEL.NS                                                   \
#                   Open        High         Low       Close       Volume
# Date
# 2022-02-01  293.100006  296.000000  218.850006  229.250000  237279096.0
# 2022-02-17         NaN         NaN         NaN         NaN          NaN
# 2022-03-01  229.250000  307.250000  215.350006  288.350006  402794713.0
# ...

# %%
# Line plot showing ZEEL stock price historical data using Ticker Module
ticker = yf.Ticker('ZEEL.NS')
zeel_df = ticker.history(period='max')
zeel_df['Close'].plot(title='ZEEL stock price')
# Out:
# <AxesSubplot:title={'center':'ZEEL stock price'}, xlabel='Date'>

# %%
# Line plot showing IRCTC stock price historical data using Ticker Module
ticker = yf.Ticker('IRCTC.NS')
irctc_df = ticker.history(period='max')
irctc_df['Close'].plot(title='IRCTC stock price')
# Out:
# <AxesSubplot:title={'center':'IRCTC stock price'}, xlabel='Date'>

# %%
zeel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4916 entries, 2002-07-01 to 2022-04-12
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          4916 non-null   float64
#  1   High          4916 non-null   float64
#  2   Low           4916 non-null   float64
#  3   Close         4916 non-null   float64
#  4   Volume        4916 non-null   int64
#  5   Dividends     4916 non-null   float64
#  6   Stock Splits  4916 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 307.2 KB

# %%
# info method of Ticker module displays all information regarding ZEEL company such as the company’s full name, business summary, 
# the industry in which it operates, on which exchange it is listed (also the country, time zone) and many more.
ticker.info
# Out:
# {'zip': '400013',
#  'sector': 'Communication Services',
#  'fullTimeEmployees': 3338,
# ...

# %%
# actions method of Ticker module displays actions such as Dividends and splits for ZEEL shares
ticker.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2002-10-21      0.275           0.0
# 2003-09-22      0.275           0.0
# 2004-09-20      0.500           0.0
# 2005-09-20      0.500           0.0
# 2006-12-18      0.500           0.0
# 2007-08-08      0.750           0.0
# 2008-07-17      1.000           0.0
# 2009-08-06      1.000           0.0
# 2010-04-29      1.000           0.0
# 2010-10-07      1.000           0.0
# 2010-11-11      0.000           2.0
# 2011-07-28      2.000           0.0
# 2012-07-05      1.500           0.0
# 2013-07-11      2.000           0.0
# 2014-07-10      2.000           0.0
# 2015-07-09      2.250           0.0
# 2016-07-21      2.250           0.0
# 2017-07-05      2.500           0.0
# 2018-07-09      2.900           0.0
# 2019-07-15      3.500           0.0
# 2020-09-10      0.300           0.0
# 2021-09-02      2.500           0.0

# %%
# institutional_holders method of Ticker module shows the institutional holders for ZEEL company, their shares and values
ticker.institutional_holders
# Out:
#                                               Holder     Shares Date Reported  \
# 0                    Invesco Developing Markets Fund  171668476    2021-10-31
# 1                  Vanguard International Value Fund   34857393    2021-10-31
# 2  Vanguard International Stock Index-Emerging Ma...   11121989    2021-10-31
# 3  Vanguard International Stock Index-Total Intl ...   10670424    2021-10-31
# 4                                Smallcap World Fund    7932200    2021-12-31
# 5             iShares Core MSCI Emerging Markets ETF    7440525    2021-12-31
# 6                    Blackrock Emerging Markets Fund    7173790    2022-01-31
# 7     Pacific Select Fund-Emerging Markets Portfolio    3152389    2021-12-31
# 8         DFA Emerging Markets Core Equity Portfolio    3106429    2021-10-31
# 9  Delaware Group Global & International Funds-Em...    2530000    2021-11-30
#
#     % Out        Value
# 0  0.1787  51663627852
# 1  0.0363  10490332423
# 2  0.0116   3347162589
# ...

# %%
# major_holders method of Ticker module shows the list of major holders for ZEEL shares
ticker.major_holders
# Out:
#         0                                      1
# 0  15.54%        % of Shares Held by All Insider
# 1  73.11%       % of Shares Held by Institutions
# 2  86.55%        % of Float Held by Institutions
# 3     106  Number of Institutions Holding Shares

# %%
# calendar method of Ticker module shows the incoming events, such as earnings

ticker.calendar
# Out:
#                                     0                    1
# Earnings Date     2022-05-18 10:59:00  2022-05-23 12:00:00
# Earnings Average                 4.57                 4.57
# Earnings Low                     3.21                 3.21
# Earnings High                    5.92                 5.92
# Revenue Average           21891800000          21891800000
# Revenue Low               20526600000          20526600000
# Revenue High              24418700000          24418700000

# %%
ZEEL.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  249.000000  249.000000  249.000000  249.000000  249.000000
# mean   257.323895  262.923695  251.761647  256.810843  255.680820
# std     57.806665   59.640331   55.834824   57.644751   58.750005
# min    167.000000  171.399994  166.800003  168.050003  165.633408
# 25%    205.449997  207.050003  201.750000  204.300003  201.362122
# 50%    257.000000  261.850006  248.050003  255.449997  255.449997
# 75%    311.000000  318.500000  304.000000  310.850006  310.850006
# max    373.950012  378.700012  366.399994  371.000000  371.000000
#
#              Volume
# count  2.490000e+02
# mean   1.961991e+07
# std    2.592317e+07
# min    1.383317e+06
# 25%    8.086625e+06
# 50%    1.326800e+07
# 75%    2.117987e+07
# max    2.186002e+08

# %%
#Plotting ZEEL Adjusted Closing price data
ZEEL['Adj Close'].plot(legend=True, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Plotting ZEEL Volume data
ZEEL['Volume'].plot(legend=True, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Calculating moving average for ZEEL for time periods of 10, 20 and 50 days and plotting it
ma_day = [10,20,50]

for ma in ma_day:
    column_name = 'MA for %s days' %(str(ma))
    ZEEL[column_name]=ZEEL['Adj Close'].rolling(ma).mean()

# %%
ZEEL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].head()
# Out:
#              Adj Close  MA for 10 days  MA for 20 days  MA for 50 days
# Date
# 2021-04-12  178.495743             NaN             NaN             NaN
# 2021-04-13  185.345810             NaN             NaN             NaN
# 2021-04-15  186.479263             NaN             NaN             NaN
# 2021-04-16  191.160950             NaN             NaN             NaN
# 2021-04-19  187.612732             NaN             NaN             NaN

# %%
ZEEL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(legend=True, figsize=(10,4))
plt.title('Moving Average for ZEEL for time periods of 10, 20 and 50 days')
# Out:
# Text(0.5, 1.0, 'Moving Average for ZEEL for time periods of 10, 20 and 50 days')

# %%
#Calculating Daily Returns for ZEEL and plotting it
ZEEL['Daily Return'] = ZEEL['Adj Close'].pct_change()
ZEEL['Daily Return'].head()
# Out:
# Date
# 2021-04-22         NaN
# 2021-04-23   -0.022361
# 2021-04-26   -0.008511
# 2021-04-27    0.009388
# 2021-04-28    0.005049
# Name: Daily Return, dtype: float64

# %%
ZEEL['Daily Return'].plot(legend=True, figsize=(10,4), linestyle='--', marker='o')
plt.title('Daily Returns for ZEEL')
# Out:
# Text(0.5, 1.0, 'Daily Returns for ZEEL')

# %%
# Distplot (Histogram + KDE) showing ZEEL Daily return
sns.distplot(ZEEL['Daily Return'].dropna(),bins=100,color='purple')
# Out:
# C:\Users\Maithily\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Return', ylabel='Density'>

# %%
# Histogram showing ZEEL Daily returns
sns.displot(ZEEL['Daily Return'].dropna(),kind='hist')

# %%
# KDE plot showing ZEEL Daily returns
sns.displot(ZEEL['Daily Return'].dropna(),kind='kde')

# %%
ZEEL["Daily Return"].hist()
# Out:
# <AxesSubplot:>

# %%
#Plotting IRCTC Adjusted Closing price data
IRCTC['Adj Close'].plot(legend=True, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Plotting IRCTC Volume data
IRCTC['Volume'].plot(legend=True, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Calculating moving average for IRCTC for time periods of 10, 20 and 50 days and plotting it
ma_day = [10,20,50]

for ma in ma_day:
    column_name = 'MA for %s days' %(str(ma))
    IRCTC[column_name]=IRCTC['Adj Close'].rolling(ma).mean()
    
IRCTC[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].head()
# Out:
#              Adj Close  MA for 10 days  MA for 20 days  MA for 50 days
# Date
# 2021-03-22  366.224304             NaN             NaN             NaN
# 2021-03-23  367.041199             NaN             NaN             NaN
# 2021-03-24  350.782715             NaN             NaN             NaN
# 2021-03-25  343.071899             NaN             NaN             NaN
# 2021-03-26  348.162659             NaN             NaN             NaN

# %%
IRCTC[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(legend=True, figsize=(10,4))
plt.title('Moving Average for IRCTC for time periods of 10, 20 and 50 days')
# Out:
# Text(0.5, 1.0, 'Moving Average for IRCTC for time periods of 10, 20 and 50 days')

# %%
#Calculating Daily Returns for IRCTC and plotting it
IRCTC['Daily Return'] = IRCTC['Adj Close'].pct_change()
IRCTC['Daily Return'].head()
# Out:
# Date
# 2021-04-15         NaN
# 2021-04-16    0.012033
# 2021-04-19   -0.009063
# 2021-04-20    0.016959
# 2021-04-22    0.020121
# Name: Daily Return, dtype: float64

# %%
IRCTC['Daily Return'].plot(legend=True, figsize=(10,4), linestyle='--', marker='o')
plt.title('Daily Returns for IRCTC')
# Out:
# Text(0.5, 1.0, 'Daily Returns for IRCTC')

# %%
# Distplot (Histogram + KDE) showing IRCTC Daily return
sns.distplot(IRCTC['Daily Return'].dropna(), bins=100, color='green')
# Out:
# C:\Users\Maithily\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Return', ylabel='Density'>

# %%
# Histogram showing IRCTC Daily return
sns.displot(IRCTC['Daily Return'].dropna(), kind='hist')

# %%
# KDE showing IRCTC Daily return
sns.displot(IRCTC['Daily Return'].dropna(), kind='kde')

# %%
# Creating a dataframe from closing prices of all stocks
closing_all = yf.download(['ZEEL.NS', 'IRCTC.NS', 'CANBK.NS', 'GITARENEW.BO'], start, end, progress=False)['Adj Close']
closing_all.head()
# Out:
#               CANBK.NS  GITARENEW.BO    IRCTC.NS     ZEEL.NS
# Date
# 2021-04-22  130.250000     31.100000  333.348663  189.534683
# 2021-04-23  130.500000     31.700001  341.109344  185.296524
# 2021-04-26  135.250000     32.299999  344.865143  183.719528
# 2021-04-27  139.649994     32.900002  357.288147  185.444351
# 2021-04-28  143.100006     33.299999  357.816132  186.380707

# %%
# Calculating daily returns from closing prices dataframe and plotting them
stock_rets = closing_all.pct_change()
stock_rets.head()
# Out:
#             CANBK.NS  GITARENEW.BO  IRCTC.NS   ZEEL.NS
# Date
# 2021-04-22       NaN           NaN       NaN       NaN
# 2021-04-23  0.001919      0.019293  0.023281 -0.022361
# 2021-04-26  0.036398      0.018927  0.011011 -0.008511
# 2021-04-27  0.032532      0.018576  0.036023  0.009388
# 2021-04-28  0.024705      0.012158  0.001478  0.005049

# %%
# Calculating the correlation between daily returns of stocks and plotting a heatmap
corr_df = stock_rets.corr()
corr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CANBK.NS to ZEEL.NS
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CANBK.NS      4 non-null      float64
#  1   GITARENEW.BO  4 non-null      float64
#  2   IRCTC.NS      4 non-null      float64
#  3   ZEEL.NS       4 non-null      float64
# dtypes: float64(4)
# memory usage: 160.0+ bytes

# %%
hm = sns.heatmap(stock_rets.dropna().corr(), annot=True)
hm.set(title='Correlation between the Daily Returns of the stocks')
plt.show()

# %%
# Plotting a heatmap to show the correlation between closing prices of stocks
hm1 = sns.heatmap(closing_all.dropna().corr(), annot=True)
hm1.set(title='Correlation between closing prices of stocks')
plt.show()

# %%
# Plotting a pairplot to show the correlation between daily returns of stocks
sns.pairplot(stock_rets.dropna())

# %%
# Plotting a pairplot to show the correlation between closing prices of stocks
sns.pairplot(closing_all.dropna())

# %%
#Above we can see all the relationships on daily returns between all the stocks by calling sns.pairplot(). 
#However we can also use sns.PairGrid() for full control of the figure, including what kind of plots go in the diagonal, the 
#upper triangle, and the lower triangle. Below is an example of utilizing the full power of seaborn to achieve this result.

# %%
returns_fig = sns.PairGrid(stock_rets.dropna())

returns_fig.map_upper(plt.scatter, color='purple')

returns_fig.map_lower(sns.kdeplot, cmap='cool_d')

returns_fig.map_diag(sns.histplot, bins=30)

# %%
# Using sns.PairGrid() to show the correlation between closing prices of stocks, also including what kind of plots 
# go in the diagonal, the upper triangle, and the lower triangle
returns_fig = sns.PairGrid(closing_all.dropna())

returns_fig.map_upper(plt.scatter, color='purple')

returns_fig.map_lower(sns.kdeplot, cmap='cool_d')

returns_fig.map_diag(sns.histplot, bins=30)

# %%
# Calculating pearsonr correlation co-efficient between IRCTC and ZEEL Daily Returns and plotting the same using jointplot
from scipy import stats
r_value, p_value = stats.pearsonr(ZEEL['Daily Return'].dropna(), IRCTC['Daily Return'].dropna())
print('r_value:' , r_value)
print('p_value:' , p_value)
# Out:
# r_value: 0.24031328180759845
# p_value: 0.0001326480724198977

# %%
import scipy.stats as stats
graph = sns.jointplot(data=stock_rets,x='ZEEL.NS', y='IRCTC.NS')
r, p = stats.pearsonr(stock_rets['ZEEL.NS'].dropna(), stock_rets['IRCTC.NS'].dropna())
# if you choose to write your own legend, then you should adjust the properties then
phantom, = graph.ax_joint.plot([], [], linestyle="", alpha=0)
# here graph is not a ax but a joint grid, so we access the axis through ax_joint method

graph.ax_joint.legend([phantom],['pearsonr={:f}, p={:f}'.format(r,p)])

# %%
rets = stock_rets.dropna()

area = np.pi*20

plt.scatter(rets.mean(), rets.std(), alpha = 0.5, s = area, color='black')

#Set the plot axis titles
plt.xlabel('Expected returns')
plt.ylabel('Risk')

# Label the scatter plots
# Reference URL: https://matplotlib.org/stable/gallery/userdemo/annotate_simple01.html?highlight=arrowprops
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (50, 50),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        arrowprops=dict(arrowstyle='->',connectionstyle = 'arc3,rad=-0.3', fc='black', ec='black'))

# %%
# Calculating Value at Risk using Bootstrap Method 
# Note the use of dropna() here, otherwise the NaN values can't be read by seaborn
sns.distplot(ZEEL['Daily Return'].dropna(),bins=100,color='purple')
# Out:
# C:\Users\Maithily\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Return', ylabel='Density'>

# %%
# The 0.05 empirical quantile of daily returns(95% confidence level)
rets['ZEEL.NS'].quantile(0.05)
# Out:
# -0.04065053213584304

# %%
# The 0.01 empirical quantile of daily returns(99% confidence level)
rets['ZEEL.NS'].quantile(0.01)
# Out:
# -0.06639583410218705

# %%
#The 0.05 empirical quantile of daily returns is at -0.040. 
#That means that with 95% confidence, our worst daily loss will not exceed 4%. 
#If we have a 1 million dollar investment, our one-day 5% VaR is 0.040 * 1,000,000 = $40,000.

# %%
# Calculating Value at Risk using Monte Carlo method
# Set up our time horizon
days = 730

# Now our delta
dt = 1/days

# Now let's grab our mu (drift) from the expected return data we got for ZEEL
mu = rets.mean()['ZEEL.NS']

# Now let's grab the volatility of the stock from the std() of the average return
sigma = rets.std()['ZEEL.NS']

# %%
def stock_monte_carlo(start_price,days,mu,sigma):
    ''' This function takes in starting stock price, days of simulation,mu,sigma, and returns simulated price array'''
    
    # Define a price array
    price = np.zeros(days)
    price[0] = start_price
    # Schok and Drift
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    # Run price array for number of days
    for x in np.arange(1,days):
        
        # Calculate Schock
        shock[x] = np.random.normal(loc=mu * dt, scale=sigma * np.sqrt(dt))
        # Calculate Drift
        drift[x] = mu * dt
        # Calculate Price
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
        
    return price

# %%
# Get start price from ZEEL.tail()
start_price = 268.950012

for run in np.arange(100):
    plt.plot(stock_monte_carlo(start_price,days,mu,sigma))
plt.xlabel("Days")
plt.ylabel("Price")  
plt.title('Monte Carlo Analysis for ZEE Entertainment')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Analysis for ZEE Entertainment')

# %%
# Set a large numebr of runs
runs = 10000

# Create an empty matrix to hold the end price data
simulations = np.zeros(runs)

for run in np.arange(runs):    
    # Set the simulation data point as the last stock price for that run
    simulations[run] = stock_monte_carlo(start_price,days,mu,sigma)[days-1];

# %%
# Now we'lll define q as the 1% empirical qunatile, this basically means that 99% of the values should fall between here
q = np.percentile(simulations, 1)
    
# Now let's plot the distribution of the end prices
plt.hist(simulations,bins=200)

# Using plt.figtext to fill in some additional information onto the plot

# Starting Price
plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for ZEE Stock after %s days" % days, weight='bold');

# %%
#Awesome! Now we have looked at the 1% empirical quantile of the final price distribution to estimate the Value at Risk 
#for the ZEEL stock, which looks to be $24.16 for every investment of 268.95 (the price of one inital zeel stock).

#This basically means for every initial stock you purchase your putting about $24.16 at risk 99% of the time 
#from our Monte Carlo Simulation.
